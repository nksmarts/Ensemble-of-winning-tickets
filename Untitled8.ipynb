# %% [markdown]
# <a href="https://colab.research.google.com/github/nksmarts/Ensemble-of-winning-tickets/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# COLA dataset
epochs_cola = [1, 2, 3]
training_loss_cola_1 = [0.479400, 0.273900, 0.167900]
validation_loss_cola_1 = [0.739961, 0.511481, 0.429722]
training_loss_cola_2 = [0.487100, 0.283300, 0.178300]
validation_loss_cola_2 = [0.662198, 0.501459, 0.399997]

# SST-2 dataset
training_loss_sst2_1 = [0.341600, 0.162200, 0.082000]
validation_loss_sst2_1 = [0.448256, 0.349870, 0.232487]
training_loss_sst2_2 = [0.337400, 0.153900, 0.070600]
validation_loss_sst2_2 = [0.436162, 0.320334, 0.219535]

plt.figure(figsize=(12, 6))

# Plotting COLA dataset losses
plt.plot(epochs_cola, training_loss_cola_1, label='COLA Training Loss Run 1', marker='o')
plt.plot(epochs_cola, validation_loss_cola_1, label='COLA Validation Loss Run 1', marker='o')
plt.plot(epochs_cola, training_loss_cola_2, label='COLA Training Loss Run 2', marker='^')
plt.plot(epochs_cola, validation_loss_cola_2, label='COLA Validation Loss Run 2', marker='^')

# Plotting SST-2 dataset losses
plt.plot(epochs_cola, training_loss_sst2_1, label='SST-2 Training Loss Run 1', marker='s')
plt.plot(epochs_cola, validation_loss_sst2_1, label='SST-2 Validation Loss Run 1', marker='s')
plt.plot(epochs_cola, training_loss_sst2_2, label='SST-2 Training Loss Run 2', marker='d')
plt.plot(epochs_cola, validation_loss_sst2_2, label='SST-2 Validation Loss Run 2', marker='d')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss vs. Epochs')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# COLA dataset
epochs = [1, 2, 3]
f1_score_cola_1 = [0.865160, 0.812274, 0.812404]
f1_score_cola_2 = [0.864503, 0.809987, 0.813158]

# SST-2 dataset
f1_score_sst2_1 = [0.940220, 0.950220, 0.960220]
f1_score_sst2_2 = [0.910220, 0.920220, 0.930220]

plt.figure(figsize=(10, 6))

# Plotting COLA dataset F1 scores
plt.plot(epochs, f1_score_cola_1, label='COLA F1 Score Run 1', marker='o')
plt.plot(epochs, f1_score_cola_2, label='COLA F1 Score Run 2', marker='^')

# Plotting SST-2 dataset F1 scores
plt.plot(epochs, f1_score_sst2_1, label='SST-2 F1 Score Run 1', marker='s')
plt.plot(epochs, f1_score_sst2_2, label='SST-2 F1 Score Run 2', marker='d')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Score vs. Epochs')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# COLA dataset
epochs = [1, 2, 3]
accuracy_cola_1 = [0.6013698630136986, 0.6273972602739726, 0.636986301369863]
accuracy_cola_2 = [0.5972602739726028, 0.6232876712328768, 0.6356164383561644]

# SST-2 dataset
accuracy_sst2_1 = [0.9319727891156463, 0.936013986013986, 0.9398601398601399]
accuracy_sst2_2 = [0.9319727891156463, 0.936013986013986, 0.9398601398601399]

plt.figure(figsize=(10, 6))

# Plotting COLA dataset accuracy scores
plt.plot(epochs, accuracy_cola_1, label='COLA Accuracy Run 1', marker='o')
plt.plot(epochs, accuracy_cola_2, label='COLA Accuracy Run 2', marker='^')

# Plotting SST-2 dataset accuracy scores
plt.plot(epochs, accuracy_sst2_1, label='SST-2 Accuracy Run 1', marker='s')
plt.plot(epochs, accuracy_sst2_2, label='SST-2 Accuracy Run 2', marker='d')

# Adding labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Score vs. Epochs')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Hypothetical step data (you can replace this with actual step data)
steps = list(range(1, 11))

# Hypothetical data for COLA dataset
train_loss_cola = [0.6, 0.58, 0.55, 0.53, 0.51, 0.49, 0.48, 0.46, 0.44, 0.42]
val_loss_cola = [0.62, 0.60, 0.57, 0.55, 0.53, 0.52, 0.50, 0.49, 0.47, 0.45]
f1_score_cola = [0.58, 0.60, 0.62, 0.63, 0.65, 0.66, 0.67, 0.68, 0.69, 0.70]
accuracy_cola = [0.60, 0.61, 0.63, 0.64, 0.65, 0.66, 0.67, 0.68, 0.69, 0.70]

# Hypothetical data for SST-2 dataset
train_loss_sst2 = [0.5, 0.48, 0.46, 0.44, 0.42, 0.40, 0.39, 0.37, 0.35, 0.33]
val_loss_sst2 = [0.52, 0.50, 0.48, 0.46, 0.45, 0.43, 0.41, 0.40, 0.38, 0.36]
f1_score_sst2 = [0.70, 0.72, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.80, 0.81]
accuracy_sst2 = [0.72, 0.73, 0.74, 0.75, 0.76, 0.77, 0.78, 0.79, 0.80, 0.81]

plt.figure(figsize=(14, 10))

# Plot for Loss
plt.subplot(3, 1, 1)
plt.plot(steps, train_loss_cola, label='COLA Training Loss', marker='o')
plt.plot(steps, val_loss_cola, label='COLA Validation Loss', marker='^')
plt.plot(steps, train_loss_sst2, label='SST-2 Training Loss', marker='s')
plt.plot(steps, val_loss_sst2, label='SST-2 Validation Loss', marker='d')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss vs. Steps')
plt.legend()
plt.grid(True)

# Plot for F1 Score
plt.subplot(3, 1, 2)
plt.plot(steps, f1_score_cola, label='COLA F1 Score', marker='o')
plt.plot(steps, f1_score_sst2, label='SST-2 F1 Score', marker='s')
plt.xlabel('Steps')
plt.ylabel('F1 Score')
plt.title('F1 Score vs. Steps')
plt.legend()
plt.grid(True)

# Plot for Accuracy
plt.subplot(3, 1, 3)
plt.plot(steps, accuracy_cola, label='COLA Accuracy', marker='o')
plt.plot(steps, accuracy_sst2, label='SST-2 Accuracy', marker='s')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Accuracy Score vs. Steps')
plt.legend()
plt.grid(True)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Hypothetical final scores
datasets = ['COLA', 'SST-2']
f1_scores = [0.85, 0.92]
accuracy_scores = [0.88, 0.93]

# Set up the bar plot
x = np.arange(len(datasets))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(10, 6))

# Bars for F1 scores
bars1 = ax.bar(x - width/2, f1_scores, width, label='F1 Score', color='blue')

# Bars for accuracy scores
bars2 = ax.bar(x + width/2, accuracy_scores, width, label='Accuracy Score', color='green')

# Add some text for labels, title, and custom x-axis tick labels, etc.
ax.set_xlabel('Dataset')
ax.set_ylabel('Scores')
ax.set_title('Comparative Final Epoch Scores by Dataset')
ax.set_xticks(x)
ax.set_xticklabels(datasets)
ax.legend()

# Add a text label above each bar in bars1 and bars2
def add_labels(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_labels(bars1)
add_labels(bars2)

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Hypothetical data
epochs = list(range(1, 14))  # Extending epochs to match the length of ensemble_iterations and eval_metrics

# Bar plot data (categorical)
ensemble_iterations = [2, 3, 5, 4, 6, 5, 7, 6, 8, 7, 8, 9, 9]
eval_metrics = [0.7, 0.72, 0.74, 0.75, 0.77, 0.78, 0.79, 0.81, 0.82, 0.83, 0.94, 0.95, 0.96]

# Line plot data (continuous)
eval_runtime = [35, 34, 33, 32, 31, 30, 29, 28, 27, 26, 25, 24, 23]
samples_per_second = [100, 105, 110, 115, 120, 125, 130, 135, 140, 145, 150, 155, 160]
steps_per_second = [10, 10.5, 11, 11.5, 12, 12.5, 13, 13.5, 14, 14.5, 15, 15.5, 16]

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Bar plot for ensemble iterations
axs[0, 0].bar(epochs, ensemble_iterations, color='blue', alpha=0.7)
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Ensemble Iterations')
axs[0, 0].set_title('Ensemble Iterations per Epoch')

# Bar plot for evaluation metrics
axs[0, 1].bar(epochs, eval_metrics, color='green', alpha=0.7)
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Evaluation Metrics')
axs[0, 1].set_title('Evaluation Metrics per Epoch')

# Line plot for eval/runtime
axs[1, 0].plot(epochs, eval_runtime, marker='o', color='red', label='Runtime')
axs[1, 0].set_xlabel('Epochs')
axs[1, 0].set_ylabel('Runtime (seconds)')
axs[1, 0].set_title('Evaluation Runtime per Epoch')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Line plot for eval/samples_per_second and eval/steps_per_second
axs[1, 1].plot(epochs, samples_per_second, marker='s', color='purple', label='Samples per Second')
axs[1, 1].plot(epochs, steps_per_second, marker='^', color='orange', label='Steps per Second')
axs[1, 1].set_xlabel('Epochs')
axs[1, 1].set_ylabel('Rate')
axs[1, 1].set_title('Samples and Steps per Second')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Hypothetical data for illustration purposes
data = {
    'Metric': ['Training Loss', 'Training Loss', 'Training Loss', 'Training Loss',
               'Validation Loss', 'Validation Loss', 'Validation Loss', 'Validation Loss',
               'F1 Score', 'F1 Score', 'F1 Score', 'F1 Score',
               'Accuracy', 'Accuracy', 'Accuracy', 'Accuracy'],
    'Value': [0.6, 0.5, 0.4, 0.3,
              0.5, 0.45, 0.42, 0.4,
              0.7, 0.75, 0.8, 0.85,
              0.72, 0.76, 0.78, 0.8],
    'Dataset': ['COLA', 'COLA', 'COLA', 'COLA',
                'COLA', 'COLA', 'COLA', 'COLA',
                'COLA', 'COLA', 'COLA', 'COLA',
                'COLA', 'COLA', 'COLA', 'COLA',
                'SST-2', 'SST-2', 'SST-2', 'SST-2',
                'SST-2', 'SST-2', 'SST-2', 'SST-2',
                'SST-2', 'SST-2', 'SST-2', 'SST-2',
                'SST-2', 'SST-2', 'SST-2', 'SST-2']
}

# Check lengths of arrays
lengths = {key: len(value) for key, value in data.items()}
max_length = max(lengths.values())

# Pad shorter lists with None to match max length
for key in data.keys():
    if len(data[key]) < max_length:
        data[key] += [None] * (max_length - len(data[key]))

# Convert to DataFrame
df = pd.DataFrame(data)

# Create box plots
plt.figure(figsize=(14, 8))
sns.boxplot(x='Metric', y='Value', hue='Dataset', data=df)
plt.title('Training Loss, Validation Loss, F1 Score, and Accuracy Score Summary')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.legend(title='Dataset')
plt.show()

# %%
# Create violin plots
plt.figure(figsize=(14, 8))
sns.violinplot(x='Metric', y='Value', hue='Dataset', data=df, split=True)
plt.title('Training Loss, Validation Loss, F1 Score, and Accuracy Score Summary')
plt.xlabel('Metrics')
plt.ylabel('Values')
plt.legend(title='Dataset')
plt.show()

# %%
import matplotlib.pyplot as plt

epochs = [1, 2, 3]
f1_scores_run1 = [0.874121, 0.878650, 0.880674]
f1_scores_run2 = [0.871049, 0.881859, 0.881246]

plt.figure(figsize=(10, 6))
plt.plot(epochs, f1_scores_run1, marker='o', linestyle='-', label='Run 1')
plt.plot(epochs, f1_scores_run2, marker='o', linestyle='-', label='Run 2')

plt.title('F1 Score on COLA Dataset')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.xticks(epochs)
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data from COLA dataset
epochs = [1, 2, 3]
accuracy_scores = [0.793864, 0.827421, 0.823586]  # Replace with actual accuracy scores

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(epochs, accuracy_scores, marker='o', linestyle='-', color='b', label='Accuracy Score')

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores Over Epochs (COLA Dataset)')
plt.xticks(epochs)
plt.ylim(0.78, 0.84)  # Adjust ylim based on your data range for better visualization
plt.grid(True)
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for COLA dataset - F1 Scores
cola_f1_scores = [
    [0.874121, 0.878650, 0.880674],
    [0.871049, 0.881859, 0.881246]
]

epochs = [1, 2, 3]

# Plotting F1 scores
plt.figure(figsize=(10, 6))
for i, scores in enumerate(cola_f1_scores):
    plt.plot(epochs, scores, marker='o', linestyle='-', label=f'Run {i+1}')

plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Scores Over Epochs (COLA Dataset)')
plt.xticks(epochs)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Data for SST-2 dataset - F1 Scores
sst2_f1_scores = [
    [0.901342, 0.901322, 0.910550],
    [0.909408, 0.910520, 0.908170]
]

# Plotting F1 scores
plt.figure(figsize=(10, 6))
for i, scores in enumerate(sst2_f1_scores):
    plt.plot(epochs, scores, marker='o', linestyle='-', label=f'Run {i+1}')

plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('F1 Scores Over Epochs (SST-2 Dataset)')
plt.xticks(epochs)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Data for SST-2 dataset - Accuracy Scores
sst2_accuracy_scores = [
    [0.909404, 0.907110, 0.905963],
    [0.910550, 0.905963, 0.909404]
]

# Plotting accuracy scores
plt.figure(figsize=(10, 6))
for i, scores in enumerate(sst2_accuracy_scores):
    plt.plot(epochs, scores, marker='o', linestyle='-', label=f'Run {i+1}')

plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores Over Epochs (SST-2 Dataset)')
plt.xticks(epochs)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for COLA dataset - Accuracy Scores
cola_accuracy_scores = [
    [0.793864, 0.827421, 0.823586],
    [0.793864, 0.827421, 0.823586]
]

# Define epochs based on the number of data points (3 epochs)
epochs = [1, 2, 3]

# Plotting accuracy scores
plt.figure(figsize=(10, 6))
for i, scores in enumerate(cola_accuracy_scores):
    plt.plot(epochs, scores, marker='o', linestyle='-', label=f'Run {i+1}')

plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores Over Epochs (COLA Dataset)')
plt.xticks(epochs)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for BERT attention heads - Training Loss, Validation Loss
epochs = [1, 2, 3]
training_loss = [0.1824, 0.1783, 0.1824]
validation_loss = [0.6874, 0.6999, 0.6874]

# Plotting Training Loss and Validation Loss
plt.figure(figsize=(10, 6))

# Plot Training Loss
plt.plot(epochs, training_loss, marker='o', linestyle='-', color='b', label='Training Loss')

# Plot Validation Loss
plt.plot(epochs, validation_loss, marker='o', linestyle='-', color='r', label='Validation Loss')

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title(' Model Efficiency (COLA Dataset)')
plt.xticks(epochs)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Heads_F1 score_COLA dataset
steps_cola = list(range(100, 3100, 100))  # Assuming steps are in increments of 100

cola_f1_score = [
    0.868993, 0.867877, 0.855601, 0.860936, 0.875289, 0.874766, 0.876031, 0.887322,
    0.889079, 0.888938, 0.897853, 0.895000, 0.897014, 0.900199, 0.924835, 0.932286,
    0.939676, 0.948197, 0.943502, 0.948628, 0.935412, 0.933502, 0.936841, 0.938369,
    0.920478, 0.927524, 0.920157, 0.910734, 0.911622, 0.901046
]

# Heads_Accuracy score_COLA dataset
cola_accuracy = [
    0.758523, 0.766059, 0.780441, 0.804276, 0.817699, 0.824142, 0.831122, 0.849070,
    0.900988, 0.908245, 0.904410, 0.914957, 0.911534, 0.924823, 0.920163, 0.933998,
    0.937009, 0.944545, 0.959751, 0.957421, 0.958380, 0.949751, 0.938380, 0.930297,
    0.923586, 0.921668, 0.918792, 0.912627, 0.906462, 0.903586
]

# Heads_F1 score_SST-2 dataset
sst2_f1_score = [
    0.858778, 0.853672, 0.853707, 0.855812, 0.860583, 0.865620, 0.867090, 0.860798,
    0.873136, 0.870168, 0.896509, 0.896250, 0.907749, 0.909078, 0.902475, 0.902509,
    0.915634, 0.928499, 0.937896, 0.945648, 0.947944, 0.950234, 0.950234, 0.969089,
    0.968253, 0.964758, 0.957112, 0.948257, 0.947074, 0.930546
]

# Heads_Accuracy_SST-2 dataset
sst2_accuracy = [
    0.872706, 0.876147, 0.882385, 0.889587, 0.893532, 0.897615, 0.896468, 0.891881,
    0.909587, 0.905642, 0.911055, 0.924495, 0.935321, 0.936789, 0.940550, 0.944817,
    0.948257, 0.955963, 0.956468, 0.959404, 0.958257, 0.964817, 0.963670, 0.965963,
    0.950229, 0.945963, 0.937110, 0.922523, 0.918257
]

# Plotting all datasets in one figure
plt.figure(figsize=(18, 12))

# Assuming steps for SST-2 are also in increments of 100, as steps_cola
steps_sst2 = list(range(100, 3100, 100))

# Plotting all datasets in one figure
plt.figure(figsize=(18, 12))

# Plot COLA F1 Score
plt.subplot(2, 2, 1)
plt.plot(steps_cola, cola_f1_score, marker='o', linestyle='-', color='b', label='COLA F1 Score')
plt.xlabel('Steps')
plt.ylabel('F1 Score')
plt.title('F1 Score - COLA Dataset')
plt.grid(True)
plt.legend()


# Plot COLA Accuracy Score
plt.subplot(2, 2, 2)
plt.plot(steps_cola, cola_accuracy, marker='s', linestyle='-', color='g', label='COLA Accuracy Score')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Accuracy Score - COLA Dataset')
plt.grid(True)
plt.legend()

# Assuming steps for SST-2 are also in increments of 100, as steps_cola
steps_sst2 = list(range(100, 3100, 100))

# Plot SST-2 F1 Score
plt.subplot(2, 2, 3)
plt.plot(steps_sst2, sst2_f1_score, marker='o', linestyle='-', color='b', label='SST-2 F1 Score')
plt.xlabel('Steps')
plt.ylabel('F1 Score')
plt.title('F1 Score - SST-2 Dataset')
plt.grid(True)
plt.legend()

# Assuming steps_sst2 should have the same length as sst2_accuracy
steps_sst2 = list(range(100, 3100, 100))  # Assuming steps are in increments of 100

# Plot SST-2 Accuracy Score
plt.figure(figsize=(12, 6))
plt.plot(steps_sst2[:29], sst2_accuracy, marker='s', linestyle='-', color='g', label='SST-2 Accuracy Score')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Accuracy Score - SST-2 Dataset')
plt.grid(True)
plt.legend()


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming steps_sst2 should have the same length as sst2_accuracy
steps_sst2 = list(range(100, 3100, 100))  # Assuming steps are in increments of 100

# Heads_Accuracy_SST-2 dataset
sst2_accuracy = [
    0.872706, 0.876147, 0.862385, 0.879587, 0.863532, 0.887615, 0.886468, 0.881881,
    0.879587, 0.895642, 0.891055, 0.894495, 0.885321, 0.896789, 0.910550, 0.904817,
    0.908257, 0.905963, 0.886468, 0.909404, 0.908257, 0.904817, 0.903670, 0.905963,
    0.900229, 0.905963, 0.907110, 0.902523, 0.908257
]

# Plot SST-2 Accuracy Score
plt.figure(figsize=(12, 6))
plt.plot(steps_sst2[:29], sst2_accuracy, marker='s', linestyle='-', color='g', label='SST-2 Accuracy Score')
plt.xlabel('Steps')
plt.ylabel('Accuracy')
plt.title('Accuracy Score - SST-2 Dataset')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for COLA dataset
cola_epochs = [1, 2, 3]
cola_f1_scores = [0.874121, 0.878650, 0.880674, 0.871049, 0.881859, 0.881246]
cola_accuracy_scores = [0.793864, 0.827421, 0.823586, 0.793864, 0.827421, 0.823586]

# Data for SST-2 dataset
sst2_epochs = [1, 2, 3]
sst2_f1_scores = [0.901342, 0.901322, 0.910550, 0.909408, 0.910520, 0.908170]
sst2_accuracy_scores = [0.909404, 0.907110, 0.905963, 0.910550, 0.905963, 0.909404]

# Plot for COLA dataset
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(cola_epochs[:3], cola_f1_scores[:3], label='Run 1 F1 Score', marker='o')
plt.plot(cola_epochs[:3], cola_accuracy_scores[:3], label='Run 1 Accuracy', marker='x')
plt.plot(cola_epochs[:3], cola_f1_scores[3:], label='Run 2 F1 Score', marker='o')
plt.plot(cola_epochs[:3], cola_accuracy_scores[3:], label='Run 2 Accuracy', marker='x')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('COLA Dataset: F1 Score vs Accuracy')
plt.legend()

# Plot for SST-2 dataset
plt.subplot(1, 2, 2)
plt.plot(sst2_epochs[:3], sst2_f1_scores[:3], label='Run 1 F1 Score', marker='o')
plt.plot(sst2_epochs[:3], sst2_accuracy_scores[:3], label='Run 1 Accuracy', marker='x')
plt.plot(sst2_epochs[:3], sst2_f1_scores[3:], label='Run 2 F1 Score', marker='o')
plt.plot(sst2_epochs[:3], sst2_accuracy_scores[3:], label='Run 2 Accuracy', marker='x')
plt.xlabel('Epoch')
plt.ylabel('Score')
plt.title('SST-2 Dataset: F1 Score vs Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
pip install matplotlib pandas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data
f1_score_data_cola = {
    "Epoch": [1, 2, 3],
    "Training Loss": [0.4794, 0.2739, 0.1679, 0.4871, 0.2833, 0.1783],
    "Validation Loss": [0.439961, 0.511481, 0.729722, 0.462198, 0.501459, 0.699997],
    "F1 Score": [0.874121, 0.87865, 0.880674, 0.871049, 0.881859, 0.881246]
}

accuracy_score_data_cola = {
    "Epoch": [1, 2, 3],
    "Training Loss": [0.4922, 0.2762, 0.1824, 0.4922, 0.2762, 0.1824],
    "Validation Loss": [0.486056, 0.499359, 0.687419, 0.486056, 0.499359, 0.687419],
    "Accuracy Score": [0.793864, 0.827421, 0.823586, 0.793864, 0.827421, 0.823586]
}

f1_score_data_sst2 = {
    "Epoch": [1, 2, 3],
    "Training Loss": [0.3416, 0.1622, 0.0820, 0.3374, 0.1539, 0.0706],
    "Validation Loss": [0.248256, 0.349870, 0.432487, 0.236162, 0.320334, 0.419535],
    "F1 Score": [0.901342, 0.901322, 0.910550, 0.909408, 0.910520, 0.908170]
}

# Ensure all lists have the same length
def adjust_lengths(data_dict):
    min_length = min(len(v) for v in data_dict.values())
    for key in data_dict:
        data_dict[key] = data_dict[key][:min_length]
    return data_dict

f1_score_data_cola = adjust_lengths(f1_score_data_cola)
accuracy_score_data_cola = adjust_lengths(accuracy_score_data_cola)
f1_score_data_sst2 = adjust_lengths(f1_score_data_sst2)

# Convert to DataFrame
df_f1_cola = pd.DataFrame(f1_score_data_cola)
df_acc_cola = pd.DataFrame(accuracy_score_data_cola)
df_f1_sst2 = pd.DataFrame(f1_score_data_sst2)

# Plotting
fig, axs = plt.subplots(3, 2, figsize=(14, 18))

# F1 Score - COLA
axs[0, 0].plot(df_f1_cola['Epoch'], df_f1_cola['Training Loss'], label='Training Loss')
axs[0, 0].plot(df_f1_cola['Epoch'], df_f1_cola['Validation Loss'], label='Validation Loss')
axs[0, 0].set_title('COLA Dataset - F1 Score - Loss')
axs[0, 0].legend()

axs[0, 1].plot(df_f1_cola['Epoch'], df_f1_cola['F1 Score'], label='F1 Score', color='green')
axs[0, 1].set_title('COLA Dataset - F1 Score')
axs[0, 1].legend()

# Accuracy Score - COLA
axs[1, 0].plot(df_acc_cola['Epoch'], df_acc_cola['Training Loss'], label='Training Loss')
axs[1, 0].plot(df_acc_cola['Epoch'], df_acc_cola['Validation Loss'], label='Validation Loss')
axs[1, 0].set_title('COLA Dataset - Accuracy - Loss')
axs[1, 0].legend()

axs[1, 1].plot(df_acc_cola['Epoch'], df_acc_cola['Accuracy Score'], label='Accuracy Score', color='orange')
axs[1, 1].set_title('COLA Dataset - Accuracy Score')
axs[1, 1].legend()

# F1 Score - SST-2
axs[2, 0].plot(df_f1_sst2['Epoch'], df_f1_sst2['Training Loss'], label='Training Loss')
axs[2, 0].plot(df_f1_sst2['Epoch'], df_f1_sst2['Validation Loss'], label='Validation Loss')
axs[2, 0].set_title('SST-2 Dataset - F1 Score - Loss')
axs[2, 0].legend()

axs[2, 1].plot(df_f1_sst2['Epoch'], df_f1_sst2['F1 Score'], label='F1 Score', color='purple')
axs[2, 1].set_title('SST-2 Dataset - F1 Score')
axs[2, 1].legend()

plt.tight_layout()
plt.show()
